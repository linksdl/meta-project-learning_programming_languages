# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Jiaqi Tu</p>

# %% [markdown]
# # CMSE 201 Final (Section 005 - Spring 2019)
#
# The goal of this final is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll load, manipulate, and plot data using Pandas and Matplotlib; fit data using NumPy and/or SciPy; and describe agent-based models and think about how to create one. You should find that you have all of the skills necessary to complete this exam having completed CMSE 201!
#
# You are encouraged to look through the entire exam before you get started so that you can appropriately budget your time and understand the broad goals of the exam. You might want to make sure you have access to any data you need and that you can get it loaded into your notebook sooner than later, in case you run into issues. Let your instructor know right away if you have problems with accessing the data.
#
# The exam is set up so that even if you get stuck on one part there are opportunities to get points on the other parts, so consider jumping ahead if you feel like you aren't making progress and then come back later if you have time.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.** If you are seen accessing your email, using a chat program (e.g. Slack), or any sort of collaborative cloud storage or document software (e.g. Google Documents), you will be at risk for receiving a zero on the exam. You are also expected to complete the exam **without** using old notebooks from class.
#
# **Keep your eyes on your screen!** Unfortunately, there isn't enough space in the room for everyone to sit at their own table so please do your best to keep your eyes on your own screen. This exam is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. If any of the instructors observe suspicious behavior, you will, again, risk receiving a zero.

# %% [markdown]
# ---
# ## Part 1: Load, manipulate, and analyze data (using Pandas and Matplotlib) (34 points)

# %% [markdown]
# In this part you are asked to load, manipulate, and visualize data using Pandas. Specifically, you'll be working with data from this article on Five Thirty Eight:
#
# [The Economic Guide To Picking A College Major](https://fivethirtyeight.com/features/the-economic-guide-to-picking-a-college-major/)
#
# Perhaps you'll find the information useful! We will be exploring median salary information, gender representation and equity, and unemployment rates for different college majors.
#
# The dataset is named `college_majors.csv`.
# The columns include:
#
# 1) `Major`: the major
# 2) `Total`: the total number of people sampled
# 3) `Men`: the total number of men
# 4) `Women`: the total number of women
# 5) `Major_category`: larger categories that majors are grouped into
# 6) `Employed`: total number employed
# 7) `Unemployed`: total number unemployed
# 8) `Median`: the median salary
# 9) `P25th`: the 25th percentile salary
# 10) `P75th`: the 75th percentile salary
# 11) `College_jobs`: number with a job requiring a college degree
# 12) `Non_college_jobs`: number with a job not requiring a college degree
# 13) `Low_wage_jobs`: number with a low wage job

# %% [markdown]
# #### Part 1, Question 1 (4 points):
# Load the data into your notebook using Pandas (__2pt__) and then use Pandas to display the first 15 rows of the data (__2pt__)

# %%
# Load data into notebook using Pandas (2pts)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
x= pd.read_csv('college_majors.csv')


# Display first 15 rows of data (2pts)
x.head(15)
# Out:
#                                     Major     Total      Men     Women  \
# 0                              ACCOUNTING  198633.0  94519.0  104114.0
# 1                       ACTUARIAL_SCIENCE    3777.0   2110.0    1667.0
# 2        ADVERTISING_AND_PUBLIC_RELATIONS   53162.0  12862.0   40300.0
# 3                   AEROSPACE_ENGINEERING   15058.0  12953.0    2105.0
# 4                  AGRICULTURAL_ECONOMICS    2439.0   1749.0     690.0
# 5   AGRICULTURE_PRODUCTION_AND_MANAGEMENT   14240.0   9658.0    4582.0
# 6                         ANIMAL_SCIENCES   21573.0   5347.0   16226.0
# 7             ANTHROPOLOGY_AND_ARCHEOLOGY   38844.0  11376.0   27468.0
# 8                     APPLIED_MATHEMATICS    4939.0   2794.0    2145.0
# 9               ARCHITECTURAL_ENGINEERING    2825.0   1835.0     990.0
# 10                           ARCHITECTURE   46420.0  25463.0   20957.0
# 11   AREA_ETHNIC_AND_CIVILIZATION_STUDIES   31195.0   8739.0   22456.0
# ...

# %% [markdown]
# #### Part 1, Question 2 (4 points):
#
# Use the "describe" function (__2pt__) to determine what the mean median salary value is for majors (that is, what is the mean median salary for the entire dataset?) (__2pt__)

# %%
# Use the describe function (2pt)
print('the mean median salary is',x['Median'].mean())
# Out:
# the mean median salary is 40151.4450867052

# %% [markdown]
# _Write your answer here for what the mean median salary is (2pt)_

# %% [markdown]
# #### Part 1, Question 3 (8 points):
#
# Women are unjustly denied equal pay compared to men. Additionally, women are unjustly excluded from Science, Technology, Engineering, and Mathematics-related fields. You wish to explore the relationships between income, unemployment, and fraction of women among different college majors.
#
# Create two new variables (__1pt__):
#
# `Unemployment_rate` = `Unemployed` / (`Employed` + `Unemployed`)
# `Fraction_women` =  `Women` / (`Men` + `Women`)
#
# Then, plot the following scatterplots.
# ___IMPORTANT___: _Give each of your plots a title, y-axis label, x-axis label, and grid.
# ___ADDITIONALLY___: _Please keep the code for subplots and figure size._
#
# Median (y-axis) vs. Unemployment_rate (x-axis) (__2pts__)
# Fraction_women (y-axis) vs. Unemployment_rate (x-axis) (__2pts__)
# Median (y-axis) vs. Fraction_women (__2pts__)
#
# Finally:
#
# Of the 3 graphs you plotted, which one shows the strongest correlation (when one variable goes up or down, the other variable goes up or down)? Which are the two variables that show the strongest correlation and describe in your own words what this correlation means (__1pt__).

# %%
# Create two new variables: Unemployment_rate and Fraction_women (1pt)

Unemployment_rate=x['Unemployed']/(x['Unemployed']+x['Employed'])
Friction_women=x['Women']/(x['Men']+x['Women'])

# Plot Median (y-axis) vs. Unemployment_rate (x-axis) (2pts)

# Keep the code for subplots and figure size
f = plt.figure(figsize=(5,10))
ax = f.add_subplot(311)

ax.plot(Unemployment_rate,x['Median'])
# Code for your plot, here


# Plot Fraction_women (y-axis) vs. Unemployment_rate (x-axis) (2pts)
ax = f.add_subplot(312)
ax.plot(Unemployment_rate,Friction_women)

# Code for your plot, here


# Median (y-axis) vs. Fraction_women (2pts)
ax=f.add_subplot(313)
ax.plot(Friction_women,x['Median'])

# Code for your plot, here


plt.tight_layout()

# %% [markdown]
# _Write your answer here for which of the 3 graphs shows the strongest correlation, which are the two variables that show the strongest correlation, and describe in your own words what this correlation means (1pt)._

# %% [markdown]
# The graph 2 shows the strongest correlation.

# %% [markdown]
# #### Part 1, Question 4 (6 points):
#
# **Using a mask**, print out all of the majors (`Major`) from the following two `Major_category` types:
#
# 1) `Psychology_and_Social_Work` (__3pts__)
# 2) `Engineering` (__3pts__)

# %%
df1=x['Major_category'].isin(['Psychology_and_Social_Work'])
Psychology_and_Social_Work=x[df1]
Psychology_and_Social_Work
# Out:
#                                          Major     Total      Men     Women  \
# 26                         CLINICAL_PSYCHOLOGY    2838.0    568.0    2270.0
# 42                       COUNSELING_PSYCHOLOGY    4626.0    931.0    3695.0
# 51                      EDUCATIONAL_PSYCHOLOGY    2854.0    522.0    2332.0
# 85   HUMAN_SERVICES_AND_COMMUNITY_ORGANIZATION    9374.0    885.0    8489.0
# 88    INDUSTRIAL_AND_ORGANIZATIONAL_PSYCHOLOGY    3014.0   1075.0    1939.0
# 124                   MISCELLANEOUS_PSYCHOLOGY    9628.0   1936.0    7692.0
# 152                                 PSYCHOLOGY  393735.0  86648.0  307087.0
# 158                          SOCIAL_PSYCHOLOGY    1386.0    413.0     973.0
# 160                                SOCIAL_WORK   53552.0   5137.0   48415.0
#
#                  Major_category  Employed  Unemployed  Median  P25th  P75th  \
# 26   Psychology_and_Social_Work      2101         368   25000  25000  40000
# ...

# %%
# Use a mask to print out all the majors of Engineering (3pts)
df2=x['Major_category'].isin(['Engineering'])
Engineering=x[df2]
Engineering
# Out:
#                                            Major    Total      Men    Women  \
# 3                          AEROSPACE_ENGINEERING  15058.0  12953.0   2105.0
# 9                      ARCHITECTURAL_ENGINEERING   2825.0   1835.0    990.0
# 10                                  ARCHITECTURE  46420.0  25463.0  20957.0
# 17                        BIOLOGICAL_ENGINEERING   8925.0   6062.0   2863.0
# 19                        BIOMEDICAL_ENGINEERING  14955.0   8407.0   6548.0
# 23                          CHEMICAL_ENGINEERING  32260.0  21239.0  11021.0
# 25                             CIVIL_ENGINEERING  53153.0  41081.0  12072.0
# 36                          COMPUTER_ENGINEERING  41542.0  33258.0   8284.0
# 52                        ELECTRICAL_ENGINEERING  81527.0  65511.0  16016.0
# 53             ELECTRICAL_ENGINEERING_TECHNOLOGY  11565.0   8181.0   3384.0
# 56         ENGINEERING_AND_INDUSTRIAL_MANAGEMENT   2906.0   2400.0    506.0
# ...

# %% [markdown]
# #### Part 1, Question 5 (4 points):
#
# Using your masks from the previous question, compute the mean median income for `Psychology_and_Social_Work` (__1pt__), `Engineering` (__1pt__), and the overall mean median income for all majors (__1pt__). Compare the 3 mean median income values and comment on your findings (__1pt__).

# %%
# Print the mean median income of Psychology_and_Social_Work (1pt)
print(Psychology_and_Social_Work['Median'].mean())

# Print the mean median income of Engineering (1pt)
print(Engineering['Median'].mean())

# Print the overall mean median income (1pt)
print(x['Median'].mean())
# Out:
# 30100.0
# 57382.75862068965
# 40151.4450867052

# %% [markdown]
# _Compare and comment on the 3 median income values (1pt)_

# %% [markdown]
# The highest median income  is engineering and the lowest is the psychology and social work.

# %% [markdown]
# #### Part 1, Question 6 (8 points):
#
# Make the following two boxplots in seaborn. You can review the documentation for making a boxplot in seaborn [here](https://seaborn.pydata.org/generated/seaborn.boxplot.html). The first example in the documentation shows how to make a single boxplot, and the 2nd example how to put multiple bloxplots into a single graph.
#
# ___IMPORTANT___: _Please keep the code for subplots and figure size. When importing seaborn, remember the small amount of code that is needed to make a seaborn plot (this is in the documentation, in case you forgot)._
#
# Plot the following:
#
# 1) A single boxplot of `Fraction_women` for all majors for the whole dataset (__3pts__)
# 2) A plot for `Fraction_women` but with a boxplot for each `Major_category` (__3pts__)
#
# Compare the overall distribution of `Fraction_women` to the `Fraction_women` for each `Major_category`. Describe the discrepancy between between the overall distribution with the distributions for each `Major_category`. (__2pts__)

# %%
# Make a boxplot of Fraction_women for all majors (3pts)
# Keep the code for subplots and figure size
# Be sure to import seaborn and use any code needed to use it, here
import seaborn as sns
sns.set(style='dark')
Friction_women=x['Women']/(x['Men']+x['Women'])

f = plt.figure(figsize=(15,5))
ax = f.add_subplot(121)


# Code for your plot, here

ax.boxplot(Friction_women,x['Major'])
# Make a graph with multiple boxplots for Fraction_women 
# for each Major_category (3pts)
ax = f.add_subplot(122)


# Code for your plot, here


# This code adds major category names at 90 degree angle to plot for readability.
# Make sure you are using column names as suggested and consistently to make this code work
ax = sns.boxplot(x=majors["Major_category"], y=majors["Fraction_women"], data=majors)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1316: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1323: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1331: RuntimeWarning: invalid value encountered in less
#   x[x < stats['whislo']],
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1332: RuntimeWarning: invalid value encountered in greater
#   x[x > stats['whishi']],
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-d3265173f291> in <module>
# ...

# %% [markdown]
# _Compare your two plots and describe the discrepancy between the overall distribution with distributions for each major category (2pts)_

# %% [markdown]
# ---
# ## Part 2: Fit data using NumPy and/or SciPy (34 points)

# %% [markdown]
# In this part of the exam, you're going to be working with a set of mystery data, aptly named "mystery.csv". Except, it's not so much a mystery! If you remember from the climate modeling you have done in the past couple weeks, CO2 levels are increasing, but they also "wobble" due to seasonal fluctuations. This data is meant to mimic this phenomenon.
#
# First off, lets make sure we get the dataset loaded into our notebook correctly.
#
# **Run the cell below!** This method for loading in the data should look familiar to you!

# %%
import numpy as np
x,y = np.loadtxt("mystery.csv",delimiter=",",unpack=True, skiprows=1)

# %% [markdown]
# **Part 2, Question 1 (4 points)**: Now that you've loaded in the data, make a plot that shows how `y` (the 2nd column) changes as a function of `x` (the 1st column). You should make sure to format your plot so that it's easy to see the relationship between `x` abd `y`. You should also include useful things like axis labels! (Also, feel free to use seaborn if you want to change the overall look of your plot, but you can use any method of plotting you are comfortable with).

# %%
# Make a plot of y vs x (4pts) 

plt.plot(x,y)

# %% [markdown]
# **Part 2, Question 2 (4 points)**: Before you start trying to fit any sort of models, what features do you see in the data? Describe patterns you see on larger (2pt) and smaller (2pt) scales.

# %% [markdown]
# Thde data is over lapped, andthe y increases as x increases

# %% [markdown]
# **Part 2, Question 3 (8 points)**: Clearly a line doesn't seem like a good choice to model the properties of this dataset. However, a second order polynomial might be a good fit!
#
# Now do the following:
#
# 1. Use NumPy's `polyfit` function to fit a polynomial of degree 2 to the data (2pts)
# 2. Use `poly1d` to create a function that can be used to plot the best fit curve on top of the data (2pts)
# 3. Generate 300 evenly spaced values between 0 and 10 and store those in a new variable called `x_model` (2pts)
# 4. Plot the data and then overplot the `y_model` values that correspond to the `x_model` values you just created. You should be able to use the function you created using `poly1d` to do this! (2pts)

# %%
# Use polyfit to fit a 2nd degree polynomial function to the data (2pts)

pfit=np.polyfit(x,y,2)

# Use poly1d to create a function based on the parameters generated from polyfit (2pts)
linear_fit=np.poly1d(pfit)

# Generate 300 evenly spaced points between 0 and 10 (2pts)
s=np.linspace(0,10,301)

# Plot your model over the actual data using the x values you just created (2pts)

plt.plot(x,y)
plt.plot(s,linear_fit(s))

# %% [markdown]
# **Part 2, Question 4 (4 points)**: How well does this model appear to fit the data? (1pt) What are the best fit parameters for this model? (1pt) Are there features that still aren't captured by this model? If so, comment on which features these are. (2pts)

# %% [markdown]
# How well does this model appear to fit the data? (1pt)
#
# Not pretty well to fit the real data.

# %%
# What are the best fit parameters for this model? 
# These were calculated in the above question using polyfit 

print(linear_fit(s))
# Out:
# [354.86728008 354.79198734 354.72161348 354.6561585  354.5956224
#  354.54000518 354.48930685 354.4435274  354.40266682 354.36672513
#  354.33570232 354.3095984  354.28841335 354.27214718 354.2607999
#  354.2543715  354.25286197 354.25627133 354.26459957 354.27784669
#  354.2960127  354.31909758 354.34710135 354.38002399 354.41786552
#  354.46062593 354.50830522 354.56090339 354.61842044 354.68085638
#  354.74821119 354.82048489 354.89767747 354.97978893 355.06681927
#  355.15876849 355.25563659 355.35742357 355.46412944 355.57575419
#  355.69229781 355.81376032 355.94014171 356.07144198 356.20766114
#  356.34879917 356.49485608 356.64583188 356.80172656 356.96254012
#  357.12827256 357.29892388 357.47449408 357.65498316 357.84039113
#  358.03071797 358.2259637  358.42612831 358.6312118  358.84121417
#  359.05613542 359.27597556 359.50073457 359.73041247 359.96500924
#  360.2045249  360.44895944 360.69831286 360.95258517 361.21177635
# ...

# %% [markdown]
# Are there features that still aren't captured by this model? If so, comment on which features these are. (2pts)

# %% [markdown]
# **Part 2, Question 5 (4 points)**: Would a higher order polynomial fit the data better? Try fitting a 10th order polynomial and plot your model on the real data (3pts) below.
#
# Is a 10th order polynomial a good fit for your data? Yes or no? Why? (1pt)

# %%
# Fit a 10th order polynomial using polyfit and poly1d and 
# plot the model on top of the data (3pts)
pfit=np.polyfit(x,y,10)
linear_fit=np.poly1d(pfit)
s=np.linspace(0,10,301)
plt.plot(x,y)
plt.plot(s,linear_fit(s))

# %% [markdown]
# _Is a 10th order polynomial a good fit for your data? Yes or no? Why? (1pt)_

# %% [markdown]
# Yes, because the 10th one fits the curve shows on real data.

# %% [markdown]
# **Part 2, Question 6 (8 points)**: Instead of just experimenting with `polyfit`, it might make more sense to use SciPy's `curve_fit` to fit a simple model to the data.
#
# As you've hopefully noticed at this point, the second order polynomial seemed to do a good job of fitting the large scale behavior of the data, but there also appears to be a periodic signal in the data as well.
#
# **Use the function below that combines a second order polynomial and a sinusoidal function and use `curve_fit` to find the best fit parameters for this new function. Please use A, B, C, and D parameters as given in the function.**
#
# `y = A*x^2 + B*sin(C*x) + D`
#
# *Hint*: You will need to use `p0` parameters that you can feed into `curve_fit` to get a model that captures the "wiggles" in the dataset as we did in class. Initial guess values for A, B, C, and D are 4, 4, 5.7, and 4, respectively.
#
# 3pts defining the function, 3pts using curve_fit to retrieve the parameters, 2pts graphing your model on top of the data

# %%
# An important import command!
from scipy.optimize import curve_fit

# Define your function here (3pts)

def fun(x,A,B,C,D):
    return (A*x**2+B*np.sin(C*x)+D)

# Use curve_fit to retrieve the parameters (3pts)
A=4
B=4
C=5.7
D=4
popt,pocv=curve_fit(fun,x,y)

# Plot your model on top of the real data (2pts)

plt.plot(x,y)
plt.plot(s,fun(s,popt[0],popt[1],popt[2],popt[3]))

# %% [markdown]
# **Part 2, Question 7 (2 points)**: Were you able to get a better looking fit for the model? How do your best fit parameters from `curve_fit` compare to the best fit parameters from your second order polynomial fit? Are any of them roughly the same? If so, discuss whether or not this what you would expect.

# %% [markdown]
# Yes

# %% [markdown]
# ---
# ## Part 3: Describe what an agent-based model is and come up with a plan for building one (32 points)

# %% [markdown]
# **Part 3, Question 1 (9 points)**: **In your own words**, describe 3 specific features that uniquely define an agent-based model compared to other types of models (3pts each).

# %% [markdown]
# *Unique feature 1 of an agent-based model (3pts)*
#
#
# *Unique feature 2 of an agent-based model (3pts)*
#
#
# *Unique feature 3 of an agent-based model (3pts)*

# %% [markdown]
# **Part 3, Question 2 (8 points)**: Give **two** examples of systems or problems that can be modeled using agent-based models and describe 1) what the agents would be and 2) what rules that control their behavior are. 2pts for describing the agents and 2pts for the rules governing their behavior for each scenario you propose. ___IMPORTANT___: __You are not allowed to propose agent-based models that were covered in class or in the question below. Be creative and think about scenarios that you could apply an agent-based model to!__

# %% [markdown]
# *Describe your 1st scenario that can be modeled using agent based modeling. 2pts for describing agents, 2pts for describing their rules of behavior*

# %% [markdown]
# *Describe your 2nd scenario that can be modeled using agent based modeling. 2pts for describing agents, 2pts for describing their rules of behavior*

# %% [markdown]
# **Part 3, Question 3 (15 points)**: After using compartmental modeling to study predator-prey relationships between sharks, seals, and humans using the [Lotka-Volterra equations](https://en.wikipedia.org/wiki/Lotka%E2%80%93Volterra_equations) you wonder if the same phenomenon could be modeled using an agent-based model. You decide to model predator-prey relationships of sharks/seals/humans using an agent-based model.
#
#
# In thinking about how one might build this model, you reflect on the fact that predators (sharks), seals (prey), and humans (bystanders, prey, and predators) all behave differently. Each group not only behaves in certain ways with respect to other groups, but with respect to their own kind (for example, social behavior travelling in packs or anti-social beahvior, travelling alone). Further, each group inhabits environments differently, with respect to shallow and deep waters, the extent to which they travel on land, and the ability to travel in the water without the aid of equipment.
#
# Your job is to **formulate a plan for an agent-based model** that for sharks/seals/humans defines the rules for how those agents behave, and describes how you would go about building the "world" that your agents live in.
#
# You should make sure you:
#
# * Define a set of rules for how your agents behave with respect to each other and other agents for each successive time step (3pts each for sharks/seals/humans)
# * Describe how you would go about defining the world that your agents lives in and any elements in the world that must exist for your agents to move, interact, etc. At minimum, your word should include land, shallow water, and deep water. 2pts each for defining how agents behave in each of these different environments.
#
# Some of your discussion should involve how you would keep track of all of the parts of your model using Python. **You do not have to write any code for this part of the exam!** However, if you wish to write some code to illustrate your point, you are welcome to do so.

# %% [markdown]
# *Define a set of rules for how your agents behave with respect to each other and other agents for each successive time step (3pts each for sharks/seals/humans)*

# %% [markdown]
# *Describe how you would go about defining the world that your agents lives in and any elements in the world that must exist for your agents to move, interact, etc. At minimum, your word should include land, shallow water, and deep water. 2pts each for defining how agents behave in each of these different environments.*

# %% [markdown]
# ---
# ## You're done! Congrats on finishing your CMSE 201 Final!
#
# Upload a copy of this notebook to the submission folder on D2L and make sure your name is on it! Thank you for a great semester!

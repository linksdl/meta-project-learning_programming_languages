# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.plot([1,0,9],[4,5,6])
plt.show()

# %%
import matplotlib.pyplot as plt


# plt.figure(figsize=(30,10), dpi =50)
plt.figure()
plt.plot([1,2,3,4,5,6,7,8],[22,25,17,21,22,24,23,22])
plt.show()

# %%
import matplotlib.pyplot as plt
import random

x = range(60)
y_shanghai = [random.uniform(15,18) for i in x]

y_beijing = [random.uniform(5,10) for i in x]

plt.figure(figsize=(20,8),dpi=80)

plt.plot(x,y_shanghai, color='r',label="Shanghai")
plt.plot(x,y_beijing, color='g',label="Beijing")

## 标签
plt.xlabel('Time Trend')
plt.ylabel('Tempature Trend')
plt.title('The city tempature change')

## 修改刻度
x_label = ["11:{}".format(i) for i in x]
plt.xticks(x[::2],x_label[::2])
plt.yticks(range(0,40,5))

plt.grid(True, linestyle='--',alpha=0.5)

plt.legend()


plt.show()

# %%
import matplotlib.pyplot as plt
import random



x = range(60)
y_shanghai = [random.uniform(15,18) for i in x]
y_beijing = [random.uniform(5,10) for i in x]


figure,axes = plt.subplots(nrows=1,ncols=2)
plt.figure(figsize=(50,50),dpi=100)

axes[0].plot(x,y_shanghai, color='r',label="Shanghai")
axes[1].plot(x,y_beijing, color='g',label="Beijing")

axes[0].legend()
axes[1].legend()

## 标签
axes[0].set_xlabel('Time Trend')
axes[0].set_ylabel('Tempature Trend')
axes[1].set_xlabel('Time Trend')
axes[1].set_ylabel('Tempature Trend')

axes[0].set_title('The city tempature change')
axes[1].set_title('The city tempature change')

## 修改刻度
x_label = ["11:{}".format(i) for i in x]
axes[0].xticks(x[::2],x_label[::2])
axes[0].yticks(range(0,40,5))
axes[1].xticks(x[::2],x_label[::2])
axes[1].yticks(range(0,40,5))

axes[0].grid(True, linestyle='--',alpha=0.5)
axes[1].grid(True, linestyle='--',alpha=0.5)




axes[0].show()
axes[1].show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-91946c1930b8> in <module>
#      29 ## 修改刻度
#      30 x_label = ["11:{}".format(i) for i in x]
# ---> 31 axes[0].xticks(x[::2],x_label[::2])
#      32 axes[0].yticks(range(0,40,5))
#      33 axes[1].xticks(x[::2],x_label[::2])
#
# AttributeError: 'AxesSubplot' object has no attribute 'xticks'

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10,10,1000)
y = x ** 3 + x**2 + x + 1

plt.figure(figsize=(10,4),dpi=80)
plt.plot(x,y)
plt.grid(linestyle='-')
plt.show()

# %%
import matplotlib.pyplot as plt


x = [12,24,46,21,32,17,22,23]
y = [1,4,2,4,3,5,3,5]


plt.figure()
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['shanghai','beijing','hangzhou','guangzhou']
y = [100,89,68,59]


plt.figure()


x_ticks = range(len(x))
plt.xticks(x_ticks,x)         
plt.bar(x_ticks,y,color=['r','g','y','b'])
plt.title('Title')
plt.grid(linestyle='--',alpha=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt

x = ['shanghai','beijing','hangzhou','guangzhou']
y_1 = [100,89,68,89]
y_2 = [120,99,98,69]


plt.figure()

x_ticks = range(len(x))
plt.xticks([i+0.11 for i in x_ticks],x)     
plt.bar(x_ticks,y_1,width=0.2)
plt.bar([i+0.22 for i in x_ticks],y_2,width=0.2)

plt.title('Title')
plt.grid(linestyle='--',alpha=0.5 )

plt.show()

# %%
import matplotlib.pyplot as plt

time = [0,15,12,66,45,22,25,38,22,43,42,44,45,39,45,25,25,5,35,30,6,43,34,41,50,55,56,60,70,43]

d = 5
g_num =  int((max(time) - min(time)) / d)

plt.figure()
plt.hist(time,bins=g_num,density=True)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['shanghai','beijing','guangzhou','nanjing']
y = [35,45,20,33]

plt.figure()
plt.pie(y,labels=x,autopct='%1.2f%%')
plt.axis('equal')
plt.legend()
plt.show()

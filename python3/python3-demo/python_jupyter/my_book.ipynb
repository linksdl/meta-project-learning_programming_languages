# %%
print('i love you')
# Out:
# i love you

# %%
a =1
b =2
print (a+b)
# Out:
# 3

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-1, 1, 50)
# y = 2*x + 1
y = x**2
plt.plot(x, y)
plt.show()

# %%
# 一级标题
## 二级标题
